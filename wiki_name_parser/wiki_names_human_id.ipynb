# %%
import requests 
import json 
import pandas as pd
import time

# %%
def timming(since):
    now=time.time() 
    s=now-since
    m=int(s/60)
    s=s-m*60
    return "%dm %ds"%(m,s)

# %%
languages=["en","fr","ru","ar","arz","ast","azb","az","bar","be_x_old","be","bg","bn","bs","ca","cs","cy","da","de","el","en","eo","es","et","eu","fa","fi","fr","ga","gl","he","hr","hu","hy","ia",
           "id","ie","io","is","it","ja","jv","ka","ko","kw","ky","la","lfn","lt","lv","mg","mk","ml","mrj","mr","ms","nl","nn","no","oc","pa","pl","pnb","pt","ro","ru","sco","sc","sh","simple","sk",
           "sl","sq","sr","sv","ta","tr","uk","ur","vep","vl","war","wuu","zh_min_nan","zh_yue","zh"]
printing_iter=10**(2)
file1=open("/content/drive/MyDrive/WunderSchild/Translation/Parser/Names_En-All/Names_En_All_human_id.txt","w")
count_links=1
count_people=0
start=time.time()
line=""

while True:
  prefix="Q"+str(count_links)
  link="https://www.wikidata.org/wiki/Special:EntityData/%s.json"%(prefix) 
  try:
    response = requests.get(link)
    if (response.status_code != 204 and response.headers["content-type"].strip().startswith("application/json")):
      try:
        person = json.loads(response.content)
        flag=1
      except ValueError: 
        flag=0
  except ValueError:
    flag=0 
  if flag==1:
    if prefix in person["entities"].keys(): 
      if "P31" in person["entities"][prefix]["claims"].keys():
        if "mainsnak" in person["entities"][prefix]["claims"]["P31"][0].keys():
          if "datavalue" in person["entities"][prefix]["claims"]["P31"][0]["mainsnak"].keys():
            if "value" in person["entities"][prefix]["claims"]["P31"][0]["mainsnak"]["datavalue"].keys():
              if "id" in person["entities"][prefix]["claims"]["P31"][0]["mainsnak"]["datavalue"]["value"].keys():
                if person["entities"][prefix]["claims"]["P31"][0]["mainsnak"]["datavalue"]["value"]["id"]=="Q5":
                  if "entities" in person.keys():   
                    if prefix in person["entities"].keys():
                      if "labels" in person["entities"][prefix].keys(): 
                        if "en" in person["entities"][prefix]["labels"].keys():
                          person_name=person["entities"][prefix]["labels"]["en"]["value"]
                          if len(person_name.split(" "))>=2:
                            count_people+=1
                            line="["+str(count_people)+"] \t"
                            person_name=person["entities"][prefix]["labels"]["en"]["value"]
                            for lang in languages:
                              if lang in person["entities"][prefix]["labels"].keys():
                                line+=lang+":"+person["entities"][prefix]["labels"][lang]["value"]+"\t"
                            line+="\n"
                            file1.write(line)
                            #print(line)
  count_links+=1
  if count_links%printing_iter==0:
    print("Imported %d names \t Tried %d links \t Last name: %s \t %s time"%(count_people,count_links,person_name,timming(start)))
# Out:
# Imported 5 names 	 Tried 100 links 	 Last name: Abraham Lincoln 	 0m 26s time
# Imported 10 names 	 Tried 200 links 	 Last name: David Cameron 	 0m 46s time
# Imported 18 names 	 Tried 300 links 	 Last name: Diego Velázquez 	 1m 14s time
# Imported 36 names 	 Tried 400 links 	 Last name: Bob Dylan 	 1m 39s time
# Imported 49 names 	 Tried 500 links 	 Last name: Ulrich Frédéric Woldemar, Comte de Lowendal 	 1m 58s time
# Imported 66 names 	 Tried 600 links 	 Last name: Luís de Camões 	 2m 16s time
# Imported 82 names 	 Tried 700 links 	 Last name: William Shakespeare 	 2m 35s time
# Imported 90 names 	 Tried 800 links 	 Last name: Stéphane Mallarmé 	 2m 58s time
# Imported 107 names 	 Tried 900 links 	 Last name: J. R. R. Tolkien 	 3m 33s time
# Imported 122 names 	 Tried 1000 links 	 Last name: Andrei Sakharov 	 4m 13s time
# Imported 135 names 	 Tried 1100 links 	 Last name: Julio Bashmore 	 4m 38s time
# Imported 142 names 	 Tried 1200 links 	 Last name: Jean-Baptiste Lully 	 5m 4s time
# Imported 170 names 	 Tried 1300 links 	 Last name: Pedro Montt 	 5m 41s time
# Imported 194 names 	 Tried 1400 links 	 Last name: Niccolò Machiavelli 	 6m 10s time
# Imported 210 names 	 Tried 1500 links 	 Last name: Ferdinand Magellan 	 6m 54s time
# Imported 223 names 	 Tried 1600 links 	 Last name: Luigi Galvani 	 7m 46s time
# Imported 259 names 	 Tried 1700 links 	 Last name: Nesta Carter 	 8m 30s time
# Imported 302 names 	 Tried 1800 links 	 Last name: Ferry Carondelet 	 9m 19s time
# Imported 314 names 	 Tried 1900 links 	 Last name: Memphis Depay 	 9m 46s time
# Imported 357 names 	 Tried 2000 links 	 Last name: Masashi Kishimoto 	 10m 9s time
# Imported 371 names 	 Tried 2100 links 	 Last name: Martial 	 10m 26s time
# Imported 382 names 	 Tried 2200 links 	 Last name: Pierre Desproges 	 10m 41s time
# Imported 387 names 	 Tried 2300 links 	 Last name: Totò 	 10m 57s time
# Imported 391 names 	 Tried 2400 links 	 Last name: Robin van Persie 	 11m 13s time
# Imported 394 names 	 Tried 2500 links 	 Last name: Ludwig Erhard 	 11m 42s time
# Imported 416 names 	 Tried 2600 links 	 Last name: Paul McCartney 	 12m 13s time
# Imported 431 names 	 Tried 2700 links 	 Last name: Arnold Schwarzenegger 	 12m 28s time
# Imported 437 names 	 Tried 2800 links 	 Last name: Geronimo 	 12m 53s time
# Imported 440 names 	 Tried 2900 links 	 Last name: Alexander Lukashenko 	 13m 10s time
# Imported 443 names 	 Tried 3000 links 	 Last name: Amy Johnson 	 13m 30s time
# Imported 451 names 	 Tried 3100 links 	 Last name: Francis van Bossuit 	 14m 10s time
# Imported 463 names 	 Tried 3200 links 	 Last name: Friedrich Wilhelm Grund 	 14m 40s time
# Imported 478 names 	 Tried 3300 links 	 Last name: Gilles-Éric Séralini 	 15m 5s time
# Imported 495 names 	 Tried 3400 links 	 Last name: Steffen Wöller 	 15m 42s time
# Imported 495 names 	 Tried 3500 links 	 Last name: Steffen Wöller 	 16m 9s time
# Imported 496 names 	 Tried 3600 links 	 Last name: Franciszek Karpiński 	 16m 50s time
# Imported 505 names 	 Tried 3700 links 	 Last name: Dennis Lawrence 	 17m 28s time
# Imported 510 names 	 Tried 3800 links 	 Last name: Laurent Dauthuille 	 18m 13s time
# Imported 514 names 	 Tried 3900 links 	 Last name: Piet Roozenburg 	 18m 46s time
# Imported 521 names 	 Tried 4000 links 	 Last name: V. P. Kalairajan 	 19m 21s time
# Imported 537 names 	 Tried 4100 links 	 Last name: Kim Carnes 	 19m 57s time
# Imported 546 names 	 Tried 4200 links 	 Last name: Jérôme Neuville 	 20m 27s time
# Imported 572 names 	 Tried 4300 links 	 Last name: Publius Flavius Vegetius Renatus 	 20m 46s time
# Imported 585 names 	 Tried 4400 links 	 Last name: Florencia de Saracho 	 21m 0s time
# Imported 605 names 	 Tried 4500 links 	 Last name: Beatritz de Dia 	 21m 29s time
# Imported 622 names 	 Tried 4600 links 	 Last name: Raúl Albiol 	 21m 45s time
# Imported 636 names 	 Tried 4700 links 	 Last name: Jean-Jacques Kieffer 	 22m 2s time
# Imported 661 names 	 Tried 4800 links 	 Last name: Michele Pellizzer 	 22m 18s time
# Imported 680 names 	 Tried 4900 links 	 Last name: Francis Marrash 	 22m 31s time
# Imported 694 names 	 Tried 5000 links 	 Last name: Emperor Jingzong of Liao 	 22m 45s time
# Imported 713 names 	 Tried 5100 links 	 Last name: Emperor Aizong of Jin 	 22m 59s time
# Imported 724 names 	 Tried 5200 links 	 Last name: Le Chastelain de Couci 	 23m 12s time
# Imported 737 names 	 Tried 5300 links 	 Last name: Bill Gates 	 23m 26s time
# Imported 769 names 	 Tried 5400 links 	 Last name: Louis Blériot 	 23m 46s time
# Imported 780 names 	 Tried 5500 links 	 Last name: Daniele Greco 	 24m 2s time
# Imported 796 names 	 Tried 5600 links 	 Last name: Peter Paul Rubens 	 24m 24s time
# Imported 826 names 	 Tried 5700 links 	 Last name: Charles Dickens 	 24m 39s time
# Imported 834 names 	 Tried 5800 links 	 Last name: Allyson Felix 	 25m 1s time
# Imported 852 names 	 Tried 5900 links 	 Last name: Johann Wolfgang von Goethe 	 25m 30s time
# Imported 860 names 	 Tried 6000 links 	 Last name: Vivian Cheruiyot 	 26m 3s time
# Imported 875 names 	 Tried 6100 links 	 Last name: Snoop Dogg 	 26m 30s time
# Imported 881 names 	 Tried 6200 links 	 Last name: Horace 	 26m 54s time
# Imported 889 names 	 Tried 6300 links 	 Last name: Olga Kaniskina 	 27m 24s time
# Imported 909 names 	 Tried 6400 links 	 Last name: Anita Włodarczyk 	 27m 52s time
# Imported 914 names 	 Tried 6500 links 	 Last name: Klaus Störtebeker 	 28m 17s time
# Imported 920 names 	 Tried 6600 links 	 Last name: Heino 	 28m 46s time
# Imported 922 names 	 Tried 6700 links 	 Last name: Alexander von Humboldt 	 29m 13s time
# Imported 927 names 	 Tried 6800 links 	 Last name: Edward Teller 	 29m 34s time
# Imported 929 names 	 Tried 6900 links 	 Last name: James Joyce 	 29m 57s time
# Imported 931 names 	 Tried 7000 links 	 Last name: Stefan Raab 	 30m 18s time
# Imported 939 names 	 Tried 7100 links 	 Last name: Emmy Noether 	 30m 47s time
# Imported 952 names 	 Tried 7200 links 	 Last name: Marcel Proust 	 31m 13s time
# Imported 1006 names 	 Tried 7300 links 	 Last name: Emperor Ling of Han 	 31m 29s time
# Imported 1048 names 	 Tried 7400 links 	 Last name: Emperor Fei of Jin 	 31m 46s time
# Imported 1127 names 	 Tried 7500 links 	 Last name: Mary the Jewess 	 32m 0s time
# Imported 1168 names 	 Tried 7600 links 	 Last name: Patricio Albacete 	 32m 15s time
# Imported 1172 names 	 Tried 7700 links 	 Last name: Franz Klammer 	 32m 29s time
# Imported 1193 names 	 Tried 7800 links 	 Last name: Bramantino 	 32m 44s time
# Imported 1198 names 	 Tried 7900 links 	 Last name: Sébastien Loeb 	 33m 0s time
# Imported 1203 names 	 Tried 8000 links 	 Last name: Lluís Llach 	 33m 14s time
# Imported 1217 names 	 Tried 8100 links 	 Last name: Louis XI of France 	 33m 45s time
# Imported 1219 names 	 Tried 8200 links 	 Last name: Carly Rose Sonenclar 	 33m 59s time
# Imported 1230 names 	 Tried 8300 links 	 Last name: David Guetta 	 34m 14s time
# Imported 1242 names 	 Tried 8400 links 	 Last name: Louis X of France 	 34m 29s time
# Imported 1256 names 	 Tried 8500 links 	 Last name: Peter the Great 	 34m 44s time
# Imported 1271 names 	 Tried 8600 links 	 Last name: Eric Barba 	 34m 59s time
# Imported 1284 names 	 Tried 8700 links 	 Last name: Juan Trippe 	 35m 16s time
# Imported 1297 names 	 Tried 8800 links 	 Last name: Aemilius Macer 	 35m 37s time
# Imported 1313 names 	 Tried 8900 links 	 Last name: Joey Moe 	 35m 51s time
# Imported 1323 names 	 Tried 9000 links 	 Last name: Mo Yan 	 36m 13s time
# Imported 1339 names 	 Tried 9100 links 	 Last name: Tabaré Vázquez 	 36m 35s time
# Imported 1361 names 	 Tried 9200 links 	 Last name: René Descartes 	 36m 56s time
# Imported 1376 names 	 Tried 9300 links 	 Last name: Manduul Khan 	 37m 13s time
# Imported 1399 names 	 Tried 9400 links 	 Last name: Silvius Magnago 	 37m 31s time
# Imported 1410 names 	 Tried 9500 links 	 Last name: Sachin 	 37m 50s time
# Imported 1429 names 	 Tried 9600 links 	 Last name: Susanne Albers 	 38m 9s time
# Imported 1441 names 	 Tried 9700 links 	 Last name: John F. Kennedy 	 38m 27s time
# Imported 1459 names 	 Tried 9800 links 	 Last name: Emperor Wenzong of Tang 	 38m 52s time
# Imported 1466 names 	 Tried 9900 links 	 Last name: Anita K. Jones 	 39m 15s time
# Imported 1480 names 	 Tried 10000 links 	 Last name: Hongzhi Emperor 	 39m 38s time
# Imported 1499 names 	 Tried 10100 links 	 Last name: Annelise Coberger 	 40m 4s time
# Imported 1513 names 	 Tried 10200 links 	 Last name: Suetonius 	 40m 23s time
# Imported 1518 names 	 Tried 10300 links 	 Last name: Manuel Valls 	 40m 41s time
# Imported 1519 names 	 Tried 10400 links 	 Last name: John McCain 	 41m 1s time
# Imported 1523 names 	 Tried 10500 links 	 Last name: Alain Prost 	 41m 21s time
# Imported 1547 names 	 Tried 10600 links 	 Last name: Sean Dyche 	 41m 39s time
# Imported 1571 names 	 Tried 10700 links 	 Last name: Gweltaz ar Fur 	 41m 55s time
# Imported 1603 names 	 Tried 10800 links 	 Last name: Jean-Alain Fanchone 	 42m 10s time
# Imported 1623 names 	 Tried 10900 links 	 Last name: Jill Scott 	 42m 27s time
# Imported 1638 names 	 Tried 11000 links 	 Last name: Karl Erckert 	 42m 48s time
# Imported 1643 names 	 Tried 11100 links 	 Last name: Valerie Solanas 	 43m 7s time
# Imported 1660 names 	 Tried 11200 links 	 Last name: Kimi Räikkönen 	 43m 26s time
# Imported 1665 names 	 Tried 11300 links 	 Last name: Farciot Edouart 	 43m 41s time
# Imported 1678 names 	 Tried 11400 links 	 Last name: Abu Ma'shar al-Balkhi 	 43m 56s time
# Imported 1696 names 	 Tried 11500 links 	 Last name: Suzy Covey 	 44m 11s time
# Imported 1716 names 	 Tried 11600 links 	 Last name: Charlotte Froese Fischer 	 44m 25s time
# Imported 1766 names 	 Tried 11700 links 	 Last name: Andreas Hofer 	 44m 40s time
# Imported 1799 names 	 Tried 11800 links 	 Last name: George Tchobanoglous 	 44m 55s time
# Imported 1830 names 	 Tried 11900 links 	 Last name: Zachary Taylor 	 45m 10s time
# Imported 1859 names 	 Tried 12000 links 	 Last name: Kylie Minogue 	 45m 25s time
# Imported 1882 names 	 Tried 12100 links 	 Last name: Jules Dubois 	 45m 40s time
# Imported 1887 names 	 Tried 12200 links 	 Last name: Rémi Garde 	 45m 56s time
# Imported 1887 names 	 Tried 12300 links 	 Last name: Rémi Garde 	 46m 11s time
# Imported 1896 names 	 Tried 12400 links 	 Last name: Shigeru Miyamoto 	 46m 27s time
# Imported 1904 names 	 Tried 12500 links 	 Last name: Patrick Janssens 	 46m 41s time
# Imported 1908 names 	 Tried 12600 links 	 Last name: Edmond Privat 	 46m 56s time
# Imported 1920 names 	 Tried 12700 links 	 Last name: Nitobe Inazō 	 47m 14s time
# Imported 1942 names 	 Tried 12800 links 	 Last name: William Auld 	 47m 30s time
# Imported 1967 names 	 Tried 12900 links 	 Last name: Humphrey Tonkin 	 47m 46s time
# Imported 2033 names 	 Tried 13000 links 	 Last name: Polydoor Lippens 	 48m 1s time
# Imported 2049 names 	 Tried 13100 links 	 Last name: Mathieu Gorgelin 	 48m 16s time
# Imported 2053 names 	 Tried 13200 links 	 Last name: Henri Laaksonen 	 48m 31s time
# Imported 2061 names 	 Tried 13300 links 	 Last name: Rudolf Thurneysen 	 48m 46s time
# Imported 2071 names 	 Tried 13400 links 	 Last name: Navum Trakhtenberg 	 49m 1s time
# Imported 2083 names 	 Tried 13500 links 	 Last name: Jean-Pierre Papin 	 49m 18s time
# Imported 2124 names 	 Tried 13600 links 	 Last name: François Quesnay 	 49m 32s time
# Imported 2125 names 	 Tried 13700 links 	 Last name: Lyudmila Peterson 	 49m 47s time
# Imported 2126 names 	 Tried 13800 links 	 Last name: Moctezuma I 	 50m 4s time
# Imported 2130 names 	 Tried 13900 links 	 Last name: Guy Fawkes 	 50m 21s time
# Imported 2134 names 	 Tried 14000 links 	 Last name: Alberto Bayo 	 50m 37s time
# Imported 2153 names 	 Tried 14100 links 	 Last name: Evi Nemeth 	 50m 53s time
# Imported 2167 names 	 Tried 14200 links 	 Last name: Ri Kwang-chon 	 51m 8s time
# Imported 2195 names 	 Tried 14300 links 	 Last name: Louis Hunter 	 51m 24s time
# Imported 2204 names 	 Tried 14400 links 	 Last name: Chun Doo-hwan 	 51m 40s time
# Imported 2211 names 	 Tried 14500 links 	 Last name: Maria Cristina of Savoy 	 51m 53s time
# Imported 2221 names 	 Tried 14600 links 	 Last name: Tracy Morgan 	 52m 7s time
# Imported 2231 names 	 Tried 14700 links 	 Last name: Seppo Hannula 	 52m 21s time
# Imported 2270 names 	 Tried 14800 links 	 Last name: Sancho Gracia 	 52m 35s time
# Imported 2271 names 	 Tried 14900 links 	 Last name: Louis Leakey 	 52m 50s time
# Imported 2286 names 	 Tried 15000 links 	 Last name: Gaston Eyskens 	 53m 4s time
# Imported 2301 names 	 Tried 15100 links 	 Last name: Louis C.K. 	 53m 18s time
# Imported 2309 names 	 Tried 15200 links 	 Last name: Jack Wilshere 	 53m 33s time
# Imported 2315 names 	 Tried 15300 links 	 Last name: Gordon Ramsay 	 53m 48s time
# Imported 2318 names 	 Tried 15400 links 	 Last name: John Randall Gillis 	 54m 2s time
# Imported 2334 names 	 Tried 15500 links 	 Last name: William Jack 	 54m 22s time
# Imported 2349 names 	 Tried 15600 links 	 Last name: Steve Hooker 	 54m 38s time
# Imported 2350 names 	 Tried 15700 links 	 Last name: Lil Wayne 	 54m 54s time
# Imported 2380 names 	 Tried 15800 links 	 Last name: Guido of Siena 	 55m 10s time
# Imported 2394 names 	 Tried 15900 links 	 Last name: Amy Winehouse 	 55m 25s time
# Imported 2417 names 	 Tried 16000 links 	 Last name: Jean-Baptiste Minne-Barth 	 55m 47s time
# Imported 2424 names 	 Tried 16100 links 	 Last name: Dana Ulery 	 56m 4s time
# Imported 2426 names 	 Tried 16200 links 	 Last name: Maurice Williamson 	 56m 22s time
# Imported 2429 names 	 Tried 16300 links 	 Last name: William Shatner 	 56m 51s time
# Imported 2445 names 	 Tried 16400 links 	 Last name: Bruce Lee 	 57m 11s time
# Imported 2483 names 	 Tried 16500 links 	 Last name: Kateryna Yushchenko 	 57m 27s time
# Imported 2488 names 	 Tried 16600 links 	 Last name: Jiang Zemin 	 57m 50s time
# Imported 2489 names 	 Tried 16700 links 	 Last name: Wen Jiabao 	 58m 13s time
# Imported 2498 names 	 Tried 16800 links 	 Last name: Ralf Schmitt 	 58m 31s time
# Imported 2532 names 	 Tried 16900 links 	 Last name: Juan Carlos Onetti 	 58m 50s time
# Imported 2544 names 	 Tried 17000 links 	 Last name: Vsevolod Solovyov 	 59m 10s time
# Imported 2566 names 	 Tried 17100 links 	 Last name: Kari Ylianttila 	 59m 32s time
# Imported 2582 names 	 Tried 17200 links 	 Last name: Paolo Nespoli 	 59m 54s time
# Imported 2584 names 	 Tried 17300 links 	 Last name: His Holiness the Dalai Lama 14 Tendzin Gyatso 	 60m 15s time
# Imported 2584 names 	 Tried 17400 links 	 Last name: His Holiness the Dalai Lama 14 Tendzin Gyatso 	 60m 31s time
# Imported 2592 names 	 Tried 17500 links 	 Last name: Cesc Fàbregas 	 60m 45s time
# Imported 2607 names 	 Tried 17600 links 	 Last name: Lawrence of Rome 	 61m 9s time
# Imported 2610 names 	 Tried 17700 links 	 Last name: Kate Bellingham 	 61m 24s time
# Imported 2614 names 	 Tried 17800 links 	 Last name: Kangxi Emperor 	 61m 44s time
# Imported 2618 names 	 Tried 17900 links 	 Last name: John Clayton 	 62m 0s time
# Imported 2621 names 	 Tried 18000 links 	 Last name: Auguste Boissonneau 	 62m 14s time
# Imported 2623 names 	 Tried 18100 links 	 Last name: Attila A. Tóth 	 62m 27s time
# Imported 2628 names 	 Tried 18200 links 	 Last name: Vilmos Aba-Novák 	 62m 45s time
# Imported 2639 names 	 Tried 18300 links 	 Last name: Zhu Rongji 	 63m 0s time
# Imported 2648 names 	 Tried 18400 links 	 Last name: Louis Armand 	 63m 19s time
# Imported 2673 names 	 Tried 18500 links 	 Last name: Bertha von Suttner 	 63m 33s time
# Imported 2681 names 	 Tried 18600 links 	 Last name: Travis Stever 	 63m 48s time
# Imported 2687 names 	 Tried 18700 links 	 Last name: Elemér Schulek 	 64m 1s time
# Imported 2705 names 	 Tried 18800 links 	 Last name: Géza Lakatos 	 64m 22s time
# Imported 2716 names 	 Tried 18900 links 	 Last name: Aly Cissokho 	 64m 44s time
# Imported 2740 names 	 Tried 19000 links 	 Last name: Junius Rusticus 	 65m 4s time
# Imported 2762 names 	 Tried 19100 links 	 Last name: Frederick Keeping 	 65m 23s time
# Imported 2778 names 	 Tried 19200 links 	 Last name: Brad Delson 	 65m 37s time
# Imported 2793 names 	 Tried 19300 links 	 Last name: Kemsit 	 65m 52s time
# Imported 2803 names 	 Tried 19400 links 	 Last name: Martin Kližan 	 66m 6s time
# Imported 2811 names 	 Tried 19500 links 	 Last name: Oscar dos Santos Emboaba Júnior 	 66m 22s time
# Imported 2816 names 	 Tried 19600 links 	 Last name: Rafael Correa Delgado 	 66m 42s time
# Imported 2819 names 	 Tried 19700 links 	 Last name: Al Gore 	 66m 56s time
# Imported 2825 names 	 Tried 19800 links 	 Last name: Cai Yuanpei 	 67m 12s time
# Imported 2835 names 	 Tried 19900 links 	 Last name: Muammar Gaddafi 	 67m 26s time
# Imported 2837 names 	 Tried 20000 links 	 Last name: Louis Bernacchi 	 67m 42s time
# Imported 2843 names 	 Tried 20100 links 	 Last name: Antonina Makarova 	 67m 57s time
# Imported 2849 names 	 Tried 20200 links 	 Last name: Joe Pesci 	 68m 17s time
# Imported 2851 names 	 Tried 20300 links 	 Last name: Li Zongren 	 68m 33s time
# Imported 2851 names 	 Tried 20400 links 	 Last name: Li Zongren 	 69m 5s time
# Imported 2853 names 	 Tried 20500 links 	 Last name: Alan Dzagoev 	 69m 27s time
# Imported 2868 names 	 Tried 20600 links 	 Last name: Georg Quedens 	 69m 46s time
# Imported 2890 names 	 Tried 20700 links 	 Last name: Aldgisl 	 70m 7s time
# Imported 2905 names 	 Tried 20800 links 	 Last name: Georges Duhamel 	 70m 33s time
# Imported 2913 names 	 Tried 20900 links 	 Last name: Robert Esnault-Pelterie 	 70m 53s time
# Imported 2918 names 	 Tried 21000 links 	 Last name: Ahn Cheol-soo 	 71m 18s time
# Imported 2926 names 	 Tried 21100 links 	 Last name: Martin Kierszenbaum 	 71m 41s time
# Imported 2931 names 	 Tried 21200 links 	 Last name: Francis Beaufort 	 72m 3s time
# Imported 2932 names 	 Tried 21300 links 	 Last name: Claus Schenk Graf von Stauffenberg 	 72m 27s time
# Imported 2933 names 	 Tried 21400 links 	 Last name: Ryo Takayasu 	 72m 48s time
# Imported 2936 names 	 Tried 21500 links 	 Last name: Katharine Burr Blodgett 	 73m 4s time
# Imported 2941 names 	 Tried 21600 links 	 Last name: Edwin Conklin 	 73m 18s time
# Imported 2943 names 	 Tried 21700 links 	 Last name: Alicia Ostriker 	 73m 37s time
# Imported 2948 names 	 Tried 21800 links 	 Last name: Dmitry Karbyshev 	 73m 57s time
# Imported 2954 names 	 Tried 21900 links 	 Last name: Eleanor Coade 	 74m 19s time
# Imported 2955 names 	 Tried 22000 links 	 Last name: Josephine Cochrane 	 74m 39s time
# Imported 2957 names 	 Tried 22100 links 	 Last name: Kalle Palander 	 74m 57s time
# Imported 2961 names 	 Tried 22200 links 	 Last name: Bev Perdue 	 75m 12s time
# Imported 2969 names 	 Tried 22300 links 	 Last name: Olympia Snowe 	 75m 27s time
# Imported 2976 names 	 Tried 22400 links 	 Last name: Chen Shui-bian 	 75m 44s time
# Imported 2977 names 	 Tried 22500 links 	 Last name: Henri Farman 	 75m 59s time
# Imported 2990 names 	 Tried 22600 links 	 Last name: Harald Schneider 	 76m 13s time
# Imported 3001 names 	 Tried 22700 links 	 Last name: Ronald Cecil Gates 	 76m 29s time
# Imported 3007 names 	 Tried 22800 links 	 Last name: Alexander Gode 	 76m 43s time
# Imported 3013 names 	 Tried 22900 links 	 Last name: Eva Lohse 	 76m 57s time
# Imported 3017 names 	 Tried 23000 links 	 Last name: Ivan Glasenberg 	 77m 12s time
# Imported 3017 names 	 Tried 23100 links 	 Last name: Ivan Glasenberg 	 77m 26s time
# Imported 3019 names 	 Tried 23200 links 	 Last name: Barnum Brown 	 77m 41s time
# Imported 3020 names 	 Tried 23300 links 	 Last name: Hideaki Anno 	 77m 54s time
# Imported 3037 names 	 Tried 23400 links 	 Last name: John McEwen 	 78m 9s time
# Imported 3051 names 	 Tried 23500 links 	 Last name: Friedrich Dürrenmatt 	 78m 22s time
# Imported 3057 names 	 Tried 23600 links 	 Last name: Benito Mussolini 	 78m 39s time
# Imported 3061 names 	 Tried 23700 links 	 Last name: Simon Stevin 	 78m 56s time
# Imported 3070 names 	 Tried 23800 links 	 Last name: Ebenezer Howard 	 79m 18s time
# Imported 3085 names 	 Tried 23900 links 	 Last name: Andrew Garfield 	 79m 33s time
# Imported 3105 names 	 Tried 24000 links 	 Last name: Tara Conner 	 79m 49s time
# Imported 3145 names 	 Tried 24100 links 	 Last name: Karen Simensen 	 80m 6s time
# Imported 3164 names 	 Tried 24200 links 	 Last name: Andrey Sheptytsky 	 80m 29s time
# Imported 3196 names 	 Tried 24300 links 	 Last name: Franz Kreisel 	 80m 43s time
# Imported 3222 names 	 Tried 24400 links 	 Last name: Agnimitra 	 81m 1s time
# Imported 3238 names 	 Tried 24500 links 	 Last name: Sophus Claussen 	 81m 22s time
# Imported 3260 names 	 Tried 24600 links 	 Last name: Bob Brown 	 81m 46s time
# Imported 3277 names 	 Tried 24700 links 	 Last name: Tursunbek Chyngyshev 	 82m 3s time
# Imported 3294 names 	 Tried 24800 links 	 Last name: Adolph von Steinwehr 	 82m 20s time
# Imported 3312 names 	 Tried 24900 links 	 Last name: Najaf Daryabandari 	 82m 42s time
# Imported 3328 names 	 Tried 25000 links 	 Last name: Cordelia Edvardson 	 82m 59s time
# Imported 3352 names 	 Tried 25100 links 	 Last name: Pope Theodosius II of Alexandria 	 83m 14s time
# Imported 3369 names 	 Tried 25200 links 	 Last name: Christopher Nolan 	 83m 34s time
# Imported 3384 names 	 Tried 25300 links 	 Last name: Dwight Howard 	 83m 49s time
# Imported 3393 names 	 Tried 25400 links 	 Last name: Ville Valo 	 84m 7s time
# Imported 3407 names 	 Tried 25500 links 	 Last name: Pál Vásárhelyi 	 84m 22s time
# Imported 3426 names 	 Tried 25600 links 	 Last name: Neil Trudinger 	 84m 36s time
# Imported 3441 names 	 Tried 25700 links 	 Last name: Pieter Helbert Damsté 	 84m 50s time
# Imported 3457 names 	 Tried 25800 links 	 Last name: Vladimir Delač 	 85m 4s time
# Imported 3489 names 	 Tried 25900 links 	 Last name: Robert Leroux 	 85m 18s time
# Imported 3534 names 	 Tried 26000 links 	 Last name: Roxana Scarlat 	 85m 32s time
# Imported 3561 names 	 Tried 26100 links 	 Last name: Chris Wood 	 85m 46s time
# Imported 3580 names 	 Tried 26200 links 	 Last name: Steven Caulker 	 86m 6s time
# Imported 3609 names 	 Tried 26300 links 	 Last name: Aksana 	 86m 21s time
# Imported 3626 names 	 Tried 26400 links 	 Last name: Jacob Kivovich Syrkin 	 86m 35s time
# Imported 3643 names 	 Tried 26500 links 	 Last name: Ladislaus I of Hungary 	 86m 51s time
# Imported 3658 names 	 Tried 26600 links 	 Last name: Antonio Conte 	 87m 10s time
# Imported 3671 names 	 Tried 26700 links 	 Last name: Lionel Richie 	 87m 26s time
# Imported 3686 names 	 Tried 26800 links 	 Last name: Han Meng 	 87m 41s time
# Imported 3701 names 	 Tried 26900 links 	 Last name: Vinod Rai 	 87m 55s time
# Imported 3721 names 	 Tried 27000 links 	 Last name: Theodor Storm 	 88m 12s time
# Imported 3730 names 	 Tried 27100 links 	 Last name: Arnaldo Pereira 	 88m 31s time
# Imported 3744 names 	 Tried 27200 links 	 Last name: Lorena Ochoa 	 88m 45s time
# Imported 3748 names 	 Tried 27300 links 	 Last name: Satoshi Shiki 	 89m 3s time
# Imported 3764 names 	 Tried 27400 links 	 Last name: Guri Berg 	 89m 19s time
# Imported 3775 names 	 Tried 27500 links 	 Last name: Daniel Mahrer 	 89m 37s time
# Imported 3799 names 	 Tried 27600 links 	 Last name: Patrick Ebert 	 89m 57s time
# Imported 3818 names 	 Tried 27700 links 	 Last name: Carlos Aranda 	 90m 20s time
# Imported 3850 names 	 Tried 27800 links 	 Last name: Macedo Novaes 	 90m 41s time
# Imported 3879 names 	 Tried 27900 links 	 Last name: Mikel Balenziaga 	 91m 4s time
# Imported 3883 names 	 Tried 28000 links 	 Last name: Hermann Möller 	 91m 19s time
# Imported 3889 names 	 Tried 28100 links 	 Last name: Adolf Eichmann 	 91m 48s time
# Imported 3901 names 	 Tried 28200 links 	 Last name: Abdus Salam 	 92m 8s time
# Imported 3915 names 	 Tried 28300 links 	 Last name: Xiong Dan 	 92m 29s time
# Imported 3920 names 	 Tried 28400 links 	 Last name: Nicky Hopkins 	 92m 54s time
# Imported 3930 names 	 Tried 28500 links 	 Last name: Brendan Sexton III 	 93m 21s time
# Imported 3938 names 	 Tried 28600 links 	 Last name: David Petraeus 	 93m 44s time
# Imported 3946 names 	 Tried 28700 links 	 Last name: John F. Burns 	 94m 4s time
# Imported 3965 names 	 Tried 28800 links 	 Last name: Jessy Mendiola 	 94m 19s time
# Imported 3979 names 	 Tried 28900 links 	 Last name: Diponegoro 	 94m 32s time
# Imported 4006 names 	 Tried 29000 links 	 Last name: Johann Strauss III 	 94m 46s time
# Imported 4032 names 	 Tried 29100 links 	 Last name: Renato Dirnei Florêncio 	 95m 8s time
# Imported 4042 names 	 Tried 29200 links 	 Last name: Thomas Boni Yayi 	 95m 22s time
# Imported 4056 names 	 Tried 29300 links 	 Last name: Carl Ritter 	 95m 41s time
# Imported 4069 names 	 Tried 29400 links 	 Last name: Hermann Heiss 	 95m 55s time
# Imported 4092 names 	 Tried 29500 links 	 Last name: Carl Jenkinson 	 96m 9s time
# Imported 4108 names 	 Tried 29600 links 	 Last name: Ricardo Alberto Frione 	 96m 21s time
# Imported 4129 names 	 Tried 29700 links 	 Last name: Hassan Mila Sesay 	 96m 34s time
# Imported 4152 names 	 Tried 29800 links 	 Last name: Adam Laxman 	 96m 47s time
# Imported 4171 names 	 Tried 29900 links 	 Last name: Faye Adell 	 97m 0s time
# Imported 4171 names 	 Tried 30000 links 	 Last name: Faye Adell 	 97m 13s time
# Imported 4172 names 	 Tried 30100 links 	 Last name: Alexandre Léonard 	 97m 25s time
# Imported 4172 names 	 Tried 30200 links 	 Last name: Alexandre Léonard 	 97m 37s time
# Imported 4173 names 	 Tried 30300 links 	 Last name: Lara Gut-Behrami 	 97m 49s time
# Imported 4173 names 	 Tried 30400 links 	 Last name: Lara Gut-Behrami 	 98m 4s time
# Imported 4175 names 	 Tried 30500 links 	 Last name: Mikhail Gorbachev 	 98m 17s time
# Imported 4189 names 	 Tried 30600 links 	 Last name: Konstantinos IX Monomachos 	 98m 31s time
# Imported 4193 names 	 Tried 30700 links 	 Last name: Rudolf Clausius 	 98m 43s time
# Imported 4200 names 	 Tried 30800 links 	 Last name: Melanie Oudin 	 98m 55s time
# Imported 4210 names 	 Tried 30900 links 	 Last name: Lalaine Vergara-Paras 	 99m 8s time
# Imported 4211 names 	 Tried 31000 links 	 Last name: Guido van Rossum 	 99m 22s time
# Imported 4221 names 	 Tried 31100 links 	 Last name: Fulgencio Berdugo 	 99m 35s time
# Imported 4242 names 	 Tried 31200 links 	 Last name: Ben Smith 	 99m 49s time
# Imported 4272 names 	 Tried 31300 links 	 Last name: Jan Mandijn 	 100m 2s time
# Imported 4282 names 	 Tried 31400 links 	 Last name: Andrew of Phu Yen 	 100m 16s time
# Imported 4303 names 	 Tried 31500 links 	 Last name: Mahmud Hotaki 	 100m 30s time
# Imported 4316 names 	 Tried 31600 links 	 Last name: Henri Émile Sauvage 	 100m 43s time
# Imported 4328 names 	 Tried 31700 links 	 Last name: Håkon Grjotgardsson 	 100m 57s time
# Imported 4361 names 	 Tried 31800 links 	 Last name: Franz Xaver Schwarz 	 101m 11s time
# Imported 4380 names 	 Tried 31900 links 	 Last name: Danni Ashe 	 101m 25s time
# Imported 4399 names 	 Tried 32000 links 	 Last name: Ažbe Jug 	 101m 39s time
# Imported 4412 names 	 Tried 32100 links 	 Last name: Henri Saivet 	 101m 52s time
# Imported 4426 names 	 Tried 32200 links 	 Last name: Katarina Ivanovska 	 102m 5s time
# Imported 4448 names 	 Tried 32300 links 	 Last name: Utkirbek Haydarov 	 102m 18s time
# Imported 4463 names 	 Tried 32400 links 	 Last name: Nina Bari 	 102m 31s time
# Imported 4488 names 	 Tried 32500 links 	 Last name: Samuel Wilson 	 102m 45s time
# Imported 4500 names 	 Tried 32600 links 	 Last name: Bilge Tegin 	 102m 59s time
# Imported 4525 names 	 Tried 32700 links 	 Last name: Evgeni Gross 	 103m 12s time
# Imported 4550 names 	 Tried 32800 links 	 Last name: David Graaff 	 103m 26s time
# Imported 4560 names 	 Tried 32900 links 	 Last name: Svetlana Boldykova 	 103m 40s time
# Imported 4573 names 	 Tried 33000 links 	 Last name: Massimo Magnani 	 103m 53s time
# Imported 4597 names 	 Tried 33100 links 	 Last name: Eugenio de Salazar 	 104m 6s time
# Imported 4607 names 	 Tried 33200 links 	 Last name: Marie Jeanne of Savoy 	 104m 20s time
# Imported 4611 names 	 Tried 33300 links 	 Last name: Leonardo Mayer 	 104m 34s time
# Imported 4613 names 	 Tried 33400 links 	 Last name: Leon Trotsky 	 104m 48s time
# Imported 4616 names 	 Tried 33500 links 	 Last name: Eugène Delacroix 	 105m 2s time
# Imported 4623 names 	 Tried 33600 links 	 Last name: Frederick Catherwood 	 105m 16s time
# Imported 4631 names 	 Tried 33700 links 	 Last name: Niclas Gerhaert van Leyden 	 105m 29s time
# Imported 4646 names 	 Tried 33800 links 	 Last name: Apostol Grezhov 	 105m 43s time
# Imported 4650 names 	 Tried 33900 links 	 Last name: Theodore Roosevelt 	 105m 56s time
# Imported 4654 names 	 Tried 34000 links 	 Last name: August Macke 	 106m 20s time
# Imported 4664 names 	 Tried 34100 links 	 Last name: Mae Jemison 	 106m 35s time
# Imported 4669 names 	 Tried 34200 links 	 Last name: Henry Fielding 	 106m 52s time
# Imported 4682 names 	 Tried 34300 links 	 Last name: Einar Vilhjálmsson 	 107m 6s time
# Imported 4688 names 	 Tried 34400 links 	 Last name: Maria Sanchez 	 107m 20s time
# Imported 4706 names 	 Tried 34500 links 	 Last name: Nahid Kulenović 	 107m 41s time
# Imported 4713 names 	 Tried 34600 links 	 Last name: James A. Garfield 	 107m 58s time
# Imported 4726 names 	 Tried 34700 links 	 Last name: William Shippen 	 108m 14s time
# Imported 4732 names 	 Tried 34800 links 	 Last name: Friedrich Engels 	 108m 29s time
# Imported 4738 names 	 Tried 34900 links 	 Last name: Esther Dyson 	 108m 54s time
# Imported 4750 names 	 Tried 35000 links 	 Last name: João Goulart 	 109m 8s time
# Imported 4753 names 	 Tried 35100 links 	 Last name: Agatha Christie 	 109m 21s time
# Imported 4757 names 	 Tried 35200 links 	 Last name: Grover Cleveland 	 109m 49s time
# Imported 4759 names 	 Tried 35300 links 	 Last name: Warren G. Harding 	 110m 22s time
# Imported 4770 names 	 Tried 35400 links 	 Last name: Asuka Sakamaki 	 111m 6s time
# Imported 4792 names 	 Tried 35500 links 	 Last name: Chester A. Arthur 	 111m 49s time
# Imported 4793 names 	 Tried 35600 links 	 Last name: Paul Cézanne 	 112m 21s time
# Imported 4805 names 	 Tried 35700 links 	 Last name: Konrad Emil Bloch 	 112m 54s time
# Imported 4818 names 	 Tried 35800 links 	 Last name: Petr Nečas 	 113m 37s time
# Imported 4822 names 	 Tried 35900 links 	 Last name: Petar Drapšin 	 114m 11s time
# Imported 4830 names 	 Tried 36000 links 	 Last name: Aria Giovanni 	 114m 44s time
# Imported 4839 names 	 Tried 36100 links 	 Last name: Valery Gerasimov 	 115m 12s time
# Imported 4848 names 	 Tried 36200 links 	 Last name: Molly Quinn 	 115m 28s time
# Imported 4863 names 	 Tried 36300 links 	 Last name: Diana Ross 	 116m 27s time
# Imported 4868 names 	 Tried 36400 links 	 Last name: Lothar Matthäus 	 116m 48s time
# Imported 4877 names 	 Tried 36500 links 	 Last name: Guglielmo Marconi 	 117m 13s time
# Imported 4880 names 	 Tried 36600 links 	 Last name: Vladimir Nabokov 	 117m 35s time
# Imported 4882 names 	 Tried 36700 links 	 Last name: Henrik Ibsen 	 117m 51s time
# Imported 4893 names 	 Tried 36800 links 	 Last name: Emīlija Benjamiņa 	 118m 5s time
# Imported 4902 names 	 Tried 36900 links 	 Last name: Joffrey Lupul 	 118m 25s time
# Imported 4910 names 	 Tried 37000 links 	 Last name: Miss Platnum 	 118m 50s time
# Imported 4933 names 	 Tried 37100 links 	 Last name: Michael IX Palaiologos 	 119m 11s time
# Imported 4946 names 	 Tried 37200 links 	 Last name: Caterina Fake 	 119m 41s time
# Imported 4952 names 	 Tried 37300 links 	 Last name: John Paul I 	 119m 56s time
# Imported 4961 names 	 Tried 37400 links 	 Last name: Robert Fournier-Sarlovèze 	 120m 9s time
# Imported 4965 names 	 Tried 37500 links 	 Last name: Pierre Curie 	 120m 32s time
# Imported 4970 names 	 Tried 37600 links 	 Last name: Theodore of Amasea 	 121m 2s time
# Imported 4980 names 	 Tried 37700 links 	 Last name: Paul Gauguin 	 121m 25s time
# Imported 4988 names 	 Tried 37800 links 	 Last name: Jean de Madre 	 121m 53s time
# Imported 4991 names 	 Tried 37900 links 	 Last name: Natalie Portman 	 122m 34s time
# Imported 4993 names 	 Tried 38000 links 	 Last name: Akihito 	 123m 13s time
# Imported 4995 names 	 Tried 38100 links 	 Last name: Lewis Carroll 	 123m 50s time
# Imported 5006 names 	 Tried 38200 links 	 Last name: Arthur Schopenhauer 	 124m 29s time
# Imported 5017 names 	 Tried 38300 links 	 Last name: Justus Jonas 	 125m 2s time
# Imported 5036 names 	 Tried 38400 links 	 Last name: Asha Bhosle 	 125m 19s time
# Imported 5039 names 	 Tried 38500 links 	 Last name: Liisa Savijarvi 	 125m 33s time
# Imported 5043 names 	 Tried 38600 links 	 Last name: Brigitte Oertli 	 125m 47s time
# Imported 5053 names 	 Tried 38700 links 	 Last name: Ľubomír Kolník 	 126m 6s time
# Imported 5059 names 	 Tried 38800 links 	 Last name: José María Ortiz de Mendíbil 	 126m 22s time
# Imported 5069 names 	 Tried 38900 links 	 Last name: Mos Def 	 126m 36s time
# Imported 5079 names 	 Tried 39000 links 	 Last name: Joseph Werbrouck 	 126m 51s time
# Imported 5087 names 	 Tried 39100 links 	 Last name: Florencia Mutio 	 127m 7s time
# Imported 5096 names 	 Tried 39200 links 	 Last name: Matthew Kavukatt 	 127m 26s time
# Imported 5110 names 	 Tried 39300 links 	 Last name: Sergei Beloglazov 	 127m 43s time
# Imported 5122 names 	 Tried 39400 links 	 Last name: Newton Cannon 	 128m 1s time
# Imported 5129 names 	 Tried 39500 links 	 Last name: Emma Watson 	 128m 15s time
# Imported 5138 names 	 Tried 39600 links 	 Last name: Christiaan Huygens 	 128m 37s time
# Imported 5151 names 	 Tried 39700 links 	 Last name: Johann Ludwig Burckhardt 	 128m 56s time
# Imported 5165 names 	 Tried 39800 links 	 Last name: Jack Nicholson 	 129m 11s time
# Imported 5168 names 	 Tried 39900 links 	 Last name: Averroes 	 129m 30s time
# Imported 5193 names 	 Tried 40000 links 	 Last name: Ptolemy XI Alexander II 	 129m 48s time
# Imported 5226 names 	 Tried 40100 links 	 Last name: Otto Schultze 	 130m 12s time
# Imported 5243 names 	 Tried 40200 links 	 Last name: Lillian Moller Gilbreth 	 130m 35s time
# Imported 5260 names 	 Tried 40300 links 	 Last name: Nelsan Ellis 	 130m 52s time
# Imported 5278 names 	 Tried 40400 links 	 Last name: Jakob Dugandžić 	 131m 7s time
# Imported 5297 names 	 Tried 40500 links 	 Last name: Pervez Musharraf 	 131m 45s time
# Imported 5314 names 	 Tried 40600 links 	 Last name: Édouard Manet 	 132m 22s time
# Imported 5326 names 	 Tried 40700 links 	 Last name: Yanis Varoufakis 	 132m 54s time
# Imported 5335 names 	 Tried 40800 links 	 Last name: Sandra Bullock 	 133m 38s time
# Imported 5340 names 	 Tried 40900 links 	 Last name: Anna Maria Jopek 	 134m 19s time
# Imported 5346 names 	 Tried 41000 links 	 Last name: Louis Cullen 	 134m 58s time
# Imported 5352 names 	 Tried 41100 links 	 Last name: Mariah Carey 	 135m 40s time
# Imported 5365 names 	 Tried 41200 links 	 Last name: Haile Selassie I 	 135m 58s time
# Imported 5383 names 	 Tried 41300 links 	 Last name: Soslan Tigiev 	 136m 15s time
# Imported 5403 names 	 Tried 41400 links 	 Last name: Josh Brolin 	 136m 44s time
# Imported 5425 names 	 Tried 41500 links 	 Last name: Sarah Guppy 	 137m 17s time
# Imported 5460 names 	 Tried 41600 links 	 Last name: Joan Higginbotham 	 137m 45s time
# Imported 5504 names 	 Tried 41700 links 	 Last name: Hanni Wenzel 	 138m 6s time
# Imported 5521 names 	 Tried 41800 links 	 Last name: Alexander Vinnikov 	 138m 21s time
# Imported 5538 names 	 Tried 41900 links 	 Last name: Kenny Miller 	 138m 35s time
# Imported 5545 names 	 Tried 42000 links 	 Last name: Democritus 	 138m 49s time
# Imported 5555 names 	 Tried 42100 links 	 Last name: Rickie Winslow 	 139m 4s time
# Imported 5563 names 	 Tried 42200 links 	 Last name: Abel Tasman 	 139m 18s time
# Imported 5571 names 	 Tried 42300 links 	 Last name: Bernhard Riemann 	 139m 33s time
# Imported 5576 names 	 Tried 42400 links 	 Last name: Mikhail Sholokhov 	 139m 48s time
# Imported 5580 names 	 Tried 42500 links 	 Last name: Katy Perry 	 140m 9s time
# Imported 5587 names 	 Tried 42600 links 	 Last name: Ted DiBiase Jr. 	 140m 26s time
# Imported 5594 names 	 Tried 42700 links 	 Last name: Frank Gorshin 	 140m 43s time
# Imported 5600 names 	 Tried 42800 links 	 Last name: Audrey Hepburn 	 141m 8s time
# Imported 5606 names 	 Tried 42900 links 	 Last name: Clement I 	 141m 23s time
# Imported 5613 names 	 Tried 43000 links 	 Last name: Golda Meir 	 141m 39s time
# Imported 5619 names 	 Tried 43100 links 	 Last name: Charles II of Navarre 	 141m 57s time
# Imported 5625 names 	 Tried 43200 links 	 Last name: Juanes 	 142m 19s time
# Imported 5635 names 	 Tried 43300 links 	 Last name: J. M. Coetzee 	 142m 48s time
# Imported 5659 names 	 Tried 43400 links 	 Last name: Robert Boyle 	 143m 16s time
# Imported 5667 names 	 Tried 43500 links 	 Last name: Erasmus 	 143m 39s time
# Imported 5678 names 	 Tried 43600 links 	 Last name: Carlos Rodas 	 143m 58s time
# Imported 5689 names 	 Tried 43700 links 	 Last name: Jean Reno 	 144m 22s time
# Imported 5740 names 	 Tried 43800 links 	 Last name: Johann Baptist Moser 	 144m 50s time
# Imported 5804 names 	 Tried 43900 links 	 Last name: Karl Obermayr 	 145m 11s time
# Imported 5851 names 	 Tried 44000 links 	 Last name: Aleksandra Bechtel 	 145m 29s time
# Imported 5883 names 	 Tried 44100 links 	 Last name: Marco Borriello 	 145m 56s time
# Imported 5919 names 	 Tried 44200 links 	 Last name: Maximilien Robespierre 	 146m 22s time
# Imported 5949 names 	 Tried 44300 links 	 Last name: Bastian Schweinsteiger 	 146m 37s time
# Imported 5987 names 	 Tried 44400 links 	 Last name: Netsky 	 146m 56s time
# Imported 6025 names 	 Tried 44500 links 	 Last name: Curveball 	 147m 19s time
# Imported 6061 names 	 Tried 44600 links 	 Last name: Edward Thurlow, 1st Baron Thurlow 	 147m 37s time
# Imported 6111 names 	 Tried 44700 links 	 Last name: Fit Finlay 	 147m 57s time
# Imported 6161 names 	 Tried 44800 links 	 Last name: Pope Alexandros of Alexandria 	 148m 19s time
# Imported 6200 names 	 Tried 44900 links 	 Last name: Brice Dja Djédjé 	 148m 37s time
# Imported 6228 names 	 Tried 45000 links 	 Last name: Max Joseph von Pettenkofer 	 148m 54s time
# Imported 6265 names 	 Tried 45100 links 	 Last name: Marcel Riesz 	 149m 16s time
# Imported 6315 names 	 Tried 45200 links 	 Last name: José Saraiva Martins 	 149m 32s time
# Imported 6356 names 	 Tried 45300 links 	 Last name: Rajko Kuzmanović 	 149m 49s time
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-1ede6bd88a51> in <module>()
#      13   link="https://www.wikidata.org/wiki/Special:EntityData/%s.json"%(prefix)
#      14   try:
# ---> 15     response = requests.get(link)
#      16     if (response.status_code != 204 and response.headers["content-type"].strip().startswith("application/json")):
#      17       try:
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.7/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/lib/python3.7/http/client.py in getresponse(self)
#    1371         try:
#    1372             try:
# -> 1373                 response.begin()
#    1374             except ConnectionError:
#    1375                 self.close()
#
# /usr/lib/python3.7/http/client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# /usr/lib/python3.7/http/client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# /usr/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /usr/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
file1.close()
